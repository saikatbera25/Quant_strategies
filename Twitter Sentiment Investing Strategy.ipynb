# %% [markdown]
# # This work is based on a training course from freeCodeCamp.org : https://www.youtube.com/watch?v=9Y3yaoi9rUQ

# %% [markdown]
# # Twitter Sentiment Investing Strategy
#
# # 1. Load Twitter Sentiment Data
#
# Load the twitter sentiment dataset, set the index, calculate the engagement ratio and filter out stocks with no significant twitter activity.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import datetime as dt
import yfinance as yf
import os
plt.style.use('ggplot')

# %%
# Offline data stored as a CSV file, so specifying path to that file

data_folder = 'C:/Users/saika/Downloads/Python_files/Quant_Strategies/Twitter_Sentiment_Data_Files'

# %%
sentiment_df = pd.read_csv(os.path.join(data_folder, 'sentiment_data.csv'))

sentiment_df
# Out:
#              date symbol  twitterPosts  twitterComments  twitterLikes  \
# 0      2021-11-18   AAPL         811.0           2592.0       21674.0
# 1      2021-11-18    ABT          21.0              3.0          13.0
# 2      2021-11-18    AMD         150.0            675.0        2949.0
# 3      2021-11-18   AMZN         557.0           1315.0       12969.0
# 4      2021-11-18   ATVI          82.0             36.0         131.0
# ...           ...    ...           ...              ...           ...
# 27230  2023-01-04    TMO          21.0              2.0          32.0
# 27231  2023-01-04   TSLA        6767.0         540711.0     3810688.0
# 27232  2023-01-04    TSN          35.0            168.0         460.0
# 27233  2023-01-04      V         132.0           1008.0        5943.0
# 27234  2023-01-04    XOM         212.0            374.0        2071.0
#
#        twitterImpressions  twitterSentiment
# 0               7981808.0               NaN
# ...

# %%
sentiment_df['date'] = pd.to_datetime(sentiment_df['date'])

sentiment_df
# Out:
#             date symbol  twitterPosts  twitterComments  twitterLikes  \
# 0     2021-11-18   AAPL         811.0           2592.0       21674.0
# 1     2021-11-18    ABT          21.0              3.0          13.0
# 2     2021-11-18    AMD         150.0            675.0        2949.0
# 3     2021-11-18   AMZN         557.0           1315.0       12969.0
# 4     2021-11-18   ATVI          82.0             36.0         131.0
# ...          ...    ...           ...              ...           ...
# 27230 2023-01-04    TMO          21.0              2.0          32.0
# 27231 2023-01-04   TSLA        6767.0         540711.0     3810688.0
# 27232 2023-01-04    TSN          35.0            168.0         460.0
# 27233 2023-01-04      V         132.0           1008.0        5943.0
# 27234 2023-01-04    XOM         212.0            374.0        2071.0
#
#        twitterImpressions  twitterSentiment
# 0               7981808.0               NaN
# 1                 64089.0               NaN
# ...

# %%
sentiment_df = sentiment_df.set_index(['date', 'symbol'])

sentiment_df
# Out:
#                    twitterPosts  twitterComments  twitterLikes  \
# date       symbol
# 2021-11-18 AAPL           811.0           2592.0       21674.0
#            ABT             21.0              3.0          13.0
#            AMD            150.0            675.0        2949.0
#            AMZN           557.0           1315.0       12969.0
#            ATVI            82.0             36.0         131.0
# ...                         ...              ...           ...
# 2023-01-04 TMO             21.0              2.0          32.0
#            TSLA          6767.0         540711.0     3810688.0
#            TSN             35.0            168.0         460.0
#            V              132.0           1008.0        5943.0
#            XOM            212.0            374.0        2071.0
#
#                    twitterImpressions  twitterSentiment
# date       symbol
# 2021-11-18 AAPL             7981808.0               NaN
#            ABT                64089.0               NaN
# ...

# %%
# Calculating/Defining and attribute to gauge the engagement

sentiment_df['engagement_ratio'] = sentiment_df['twitterComments']/sentiment_df['twitterLikes']

sentiment_df
# Out:
#                    twitterPosts  twitterComments  twitterLikes  \
# date       symbol
# 2021-11-18 AAPL           811.0           2592.0       21674.0
#            ABT             21.0              3.0          13.0
#            AMD            150.0            675.0        2949.0
#            AMZN           557.0           1315.0       12969.0
#            ATVI            82.0             36.0         131.0
# ...                         ...              ...           ...
# 2023-01-04 TMO             21.0              2.0          32.0
#            TSLA          6767.0         540711.0     3810688.0
#            TSN             35.0            168.0         460.0
#            V              132.0           1008.0        5943.0
#            XOM            212.0            374.0        2071.0
#
#                    twitterImpressions  twitterSentiment  engagement_ratio
# date       symbol
# 2021-11-18 AAPL             7981808.0               NaN          0.119590
# ...

# %%
sentiment_df = sentiment_df[(sentiment_df['twitterLikes']>20)&(sentiment_df['twitterComments']>10)]

sentiment_df
# Out:
#                    twitterPosts  twitterComments  twitterLikes  \
# date       symbol
# 2021-11-18 AAPL           811.0           2592.0       21674.0
#            AMD            150.0            675.0        2949.0
#            AMZN           557.0           1315.0       12969.0
#            ATVI            82.0             36.0         131.0
#            BA              61.0             55.0         342.0
# ...                         ...              ...           ...
# 2023-01-04 T              184.0           3409.0       14271.0
#            TSLA          6767.0         540711.0     3810688.0
#            TSN             35.0            168.0         460.0
#            V              132.0           1008.0        5943.0
#            XOM            212.0            374.0        2071.0
#
#                    twitterImpressions  twitterSentiment  engagement_ratio
# date       symbol
# 2021-11-18 AAPL             7981808.0               NaN          0.119590
# ...

# %% [markdown]
# # 2. Aggregate Monthly and calculate average sentiment for the month
#
# Aggregate on a monthly level and calculate average monthly metric, for the one we choose
#
# We will select to invest in the top five stocks every month for the next month

# %%
sentiment_df.reset_index('symbol')
# Out:
#            symbol  twitterPosts  twitterComments  twitterLikes  \
# date
# 2021-11-18   AAPL         811.0           2592.0       21674.0
# 2021-11-18    AMD         150.0            675.0        2949.0
# 2021-11-18   AMZN         557.0           1315.0       12969.0
# 2021-11-18   ATVI          82.0             36.0         131.0
# 2021-11-18     BA          61.0             55.0         342.0
# ...           ...           ...              ...           ...
# 2023-01-04      T         184.0           3409.0       14271.0
# 2023-01-04   TSLA        6767.0         540711.0     3810688.0
# 2023-01-04    TSN          35.0            168.0         460.0
# 2023-01-04      V         132.0           1008.0        5943.0
# 2023-01-04    XOM         212.0            374.0        2071.0
#
#             twitterImpressions  twitterSentiment  engagement_ratio
# date
# 2021-11-18           7981808.0               NaN          0.119590
# ...

# %%
sentiment_df.reset_index('symbol').groupby([pd.Grouper(freq='M'), 'symbol'])

sentiment_df
# Out:
#                    twitterPosts  twitterComments  twitterLikes  \
# date       symbol
# 2021-11-18 AAPL           811.0           2592.0       21674.0
#            AMD            150.0            675.0        2949.0
#            AMZN           557.0           1315.0       12969.0
#            ATVI            82.0             36.0         131.0
#            BA              61.0             55.0         342.0
# ...                         ...              ...           ...
# 2023-01-04 T              184.0           3409.0       14271.0
#            TSLA          6767.0         540711.0     3810688.0
#            TSN             35.0            168.0         460.0
#            V              132.0           1008.0        5943.0
#            XOM            212.0            374.0        2071.0
#
#                    twitterImpressions  twitterSentiment  engagement_ratio
# date       symbol
# 2021-11-18 AAPL             7981808.0               NaN          0.119590
# ...

# %%
(sentiment_df.reset_index('symbol').groupby([pd.Grouper(freq='M'), 'symbol'])
[['engagement_ratio']].mean())
# Out:
#                    engagement_ratio
# date       symbol
# 2021-11-30 AAL             0.203835
#            AAPL            0.256318
#            ABBV            0.244677
#            ABT             0.313368
#            AES             0.864613
# ...                             ...
# 2023-01-31 TMO             0.333313
#            TSLA            0.151992
#            TSN             0.280553
#            V               0.194045
#            XOM             0.217904
#
# [1109 rows x 1 columns]

# %%
aggregated_df = (sentiment_df.reset_index('symbol').groupby([pd.Grouper(freq='M'), 'symbol'])
                [['engagement_ratio']].mean())

aggregated_df
# Out:
#                    engagement_ratio
# date       symbol
# 2021-11-30 AAL             0.203835
#            AAPL            0.256318
#            ABBV            0.244677
#            ABT             0.313368
#            AES             0.864613
# ...                             ...
# 2023-01-31 TMO             0.333313
#            TSLA            0.151992
#            TSN             0.280553
#            V               0.194045
#            XOM             0.217904
#
# [1109 rows x 1 columns]

# %%
aggregated_df['rank'] = (aggregated_df.groupby(level=0)['engagement_ratio']
                          .transform(lambda x: x.rank(ascending=False)))

aggregated_df
# Out:
#                    engagement_ratio  rank
# date       symbol
# 2021-11-30 AAL             0.203835  37.0
#            AAPL            0.256318  23.0
#            ABBV            0.244677  26.0
#            ABT             0.313368  14.0
#            AES             0.864613   2.0
# ...                             ...   ...
# 2023-01-31 TMO             0.333313  19.0
#            TSLA            0.151992  72.0
#            TSN             0.280553  30.0
#            V               0.194045  60.0
#            XOM             0.217904  53.0
#
# [1109 rows x 2 columns]

# %% [markdown]
# # 3. Select the top 5 stocks based on their cross-sectional ranking for each month
#
# Select top 5 stocks by rank for each month and fix the date to start at begining of next month

# %%
aggregated_df[aggregated_df['rank']<6]
# Out:
#                    engagement_ratio  rank
# date       symbol
# 2021-11-30 AES             0.864613   2.0
#            FCX             0.626323   5.0
#            MNST            0.699721   3.0
#            OXY             2.147741   1.0
#            SLB             0.647374   4.0
# ...                             ...   ...
# 2023-01-31 A               0.471572   5.0
#            AES             0.533809   4.0
#            BIIB            0.839303   1.0
#            FCX             0.667387   3.0
#            MDT             0.806841   2.0
#
# [75 rows x 2 columns]

# %%
filtered_df = aggregated_df[aggregated_df['rank']<6].copy()

filtered_df
# Out:
#                    engagement_ratio  rank
# date       symbol
# 2021-11-30 AES             0.864613   2.0
#            FCX             0.626323   5.0
#            MNST            0.699721   3.0
#            OXY             2.147741   1.0
#            SLB             0.647374   4.0
# ...                             ...   ...
# 2023-01-31 A               0.471572   5.0
#            AES             0.533809   4.0
#            BIIB            0.839303   1.0
#            FCX             0.667387   3.0
#            MDT             0.806841   2.0
#
# [75 rows x 2 columns]

# %%
filtered_df = filtered_df.reset_index(level=1)

filtered_df
# Out:
#            symbol  engagement_ratio  rank
# date
# 2021-11-30    AES          0.864613   2.0
# 2021-11-30    FCX          0.626323   5.0
# 2021-11-30   MNST          0.699721   3.0
# 2021-11-30    OXY          2.147741   1.0
# 2021-11-30    SLB          0.647374   4.0
# ...           ...               ...   ...
# 2023-01-31      A          0.471572   5.0
# 2023-01-31    AES          0.533809   4.0
# 2023-01-31   BIIB          0.839303   1.0
# 2023-01-31    FCX          0.667387   3.0
# 2023-01-31    MDT          0.806841   2.0
#
# [75 rows x 3 columns]

# %%
filtered_df.index = filtered_df.index+pd.DateOffset(1)

filtered_df
# Out:
#            symbol  engagement_ratio  rank
# date
# 2021-12-01    AES          0.864613   2.0
# 2021-12-01    FCX          0.626323   5.0
# 2021-12-01   MNST          0.699721   3.0
# 2021-12-01    OXY          2.147741   1.0
# 2021-12-01    SLB          0.647374   4.0
# ...           ...               ...   ...
# 2023-02-01      A          0.471572   5.0
# 2023-02-01    AES          0.533809   4.0
# 2023-02-01   BIIB          0.839303   1.0
# 2023-02-01    FCX          0.667387   3.0
# 2023-02-01    MDT          0.806841   2.0
#
# [75 rows x 3 columns]

# %%
filtered_df = filtered_df.reset_index().set_index(['date', 'symbol'])

filtered_df.head(20)
# Out:
#                    engagement_ratio  rank
# date       symbol
# 2021-12-01 AES             0.864613   2.0
#            FCX             0.626323   5.0
#            MNST            0.699721   3.0
#            OXY             2.147741   1.0
#            SLB             0.647374   4.0
# 2022-01-01 D               0.801994   5.0
#            FCX             0.841220   4.0
#            L               6.507246   1.0
#            LUV             1.303215   2.0
#            MA              0.883401   3.0
# 2022-02-01 AMD             0.715556   4.0
#            D               1.136678   1.0
#            FCX             0.655237   5.0
#            LUV             1.035258   2.0
#            MA              0.729063   3.0
# 2022-03-01 FCX             1.138332   2.0
#            GILD            0.530886   5.0
#            LUV             1.574377   1.0
#            MRO             0.581748   4.0
#            OXY             1.025579   3.0

# %% [markdown]
# # 4. Extract the stocks to form portfolios with at the start of each new month
#
# Create a dictionary containing start of month and corresponding selected stocks

# %%
dates = filtered_df.index.get_level_values('date').unique().tolist()

fixed_dates = {}

for d in dates:
    
    fixed_dates[d.strftime('%Y-%m-%d')] = filtered_df.xs(d, level=0).index.tolist()
    
fixed_dates
# Out:
# {'2021-12-01': ['AES', 'FCX', 'MNST', 'OXY', 'SLB'],
#  '2022-01-01': ['D', 'FCX', 'L', 'LUV', 'MA'],
#  '2022-02-01': ['AMD', 'D', 'FCX', 'LUV', 'MA'],
#  '2022-03-01': ['FCX', 'GILD', 'LUV', 'MRO', 'OXY'],
#  '2022-04-01': ['A', 'CRM', 'PFE', 'PM', 'STZ'],
#  '2022-05-01': ['AMD', 'CRM', 'CVX', 'J', 'KEY'],
#  '2022-06-01': ['AMD', 'DD', 'FCX', 'KEY', 'LMT'],
#  '2022-07-01': ['CB', 'CRM', 'DD', 'FCX', 'STZ'],
#  '2022-08-01': ['A', 'DD', 'JPM', 'REGN', 'STZ'],
#  '2022-09-01': ['ABT', 'DIS', 'L', 'META', 'MRNA'],
#  '2022-10-01': ['J', 'KEY', 'L', 'META', 'MU'],
#  '2022-11-01': ['A', 'DD', 'FCX', 'J', 'META'],
#  '2022-12-01': ['AEP', 'AES', 'DD', 'J', 'STZ'],
#  '2023-01-01': ['A', 'AES', 'DAL', 'J', 'KEY'],
#  '2023-02-01': ['A', 'AES', 'BIIB', 'FCX', 'MDT']}

# %% [markdown]
# # 5. Download fresh stock prices for only selected/shortlisted stocks

# %%
stocks_list = sentiment_df.index.get_level_values('symbol').unique().tolist()

prices_df = yf.download(tickers=stocks_list,
                        start='2021-01-01',
                        end='2023-03-01')
# Out:
# [*********************100%%**********************]  85 of 85 completed
# 1 Failed download:
# ['ATVI']: Exception('%ticker%: No timezone found, symbol may be delisted')

# %%
prices_df
# Out:
#              Adj Close                                                         \
#                      A    AAL         AAP        AAPL        ABBV         ABT
# Date
# 2021-01-04  116.384750  15.13  145.845108  127.164146   93.054276  103.105186
# 2021-01-05  117.336304  15.43  145.687515  128.736389   94.016502  104.380905
# 2021-01-06  120.553955  15.52  154.104156  124.402924   93.204346  104.163551
# 2021-01-07  123.761787  15.38  155.420410  128.647934   94.201889  105.174667
# 2021-01-08  124.644691  15.13  157.635788  129.758362   94.696236  105.467606
# ...                ...    ...         ...         ...         ...         ...
# 2023-02-22  141.055099  15.56  140.077377  148.308395  146.196243  100.645607
# 2023-02-23  142.167038  15.87  138.507080  148.796402  147.554672  100.508400
# 2023-02-24  140.181458  15.56  135.425034  146.117279  148.175674   98.459991
# 2023-02-27  141.154388  15.63  137.161133  147.322388  149.699051   97.783737
# ...

# %% [markdown]
# # 6. Calculate Portfolio Return with monthly rebalancing

# %%
returns_df = np.log(prices_df['Adj Close']).diff().dropna()

returns_df
# Out:
# Empty DataFrame
# Columns: [A, AAL, AAP, AAPL, ABBV, ABT, AEP, AES, ALB, AMD, AMZN, ATVI, AVGO, BA, BIIB, BKR, BMY, C, CB, CCL, CMG, CRM, CVX, D, DAL, DD, DG, DIS, DLTR, DVN, EA, EBAY, EL, ENPH, ES, F, FCX, GILD, GOOG, GOOGL, GS, HBAN, HON, ILMN, INTC, J, JNJ, JPM, K, KEY, KO, L, LMT, LUV, MA, MDT, META, MNST, MO, MPC, MRNA, MRO, MSFT, MU, NCLH, NFLX, NKE, NUE, NVDA, OXY, PEP, PFE, PG, PM, PYPL, RCL, REGN, SLB, STZ, T, TMO, TSLA, TSN, V, XOM]
# Index: []
#
# [0 rows x 85 columns]

# %% [markdown]
# The above issue is happening because the ['ATVI'] stock has been delisted and somehow because of that every row in the dataframe gets a NaN value
#
# To resolve that, remove the ['ATVI'] stock from the stocks_list and then get the prices data as shown below

# %%
stocks_list = sentiment_df.index.get_level_values('symbol').unique().tolist()

stocks_list.remove('ATVI')

prices_df = yf.download(tickers=stocks_list,
                        start='2021-01-01',
                        end='2023-03-01')
# Out:
# [*********************100%%**********************]  84 of 84 completed

# %%
returns_df = np.log(prices_df['Adj Close']).diff().dropna()

returns_df
# Out:
#                    A       AAL       AAP      AAPL      ABBV       ABT  \
# Date
# 2021-01-05  0.008143  0.019634 -0.001081  0.012288  0.010287  0.012297
# 2021-01-06  0.027053  0.005816  0.056165 -0.034241 -0.008676 -0.002084
# 2021-01-07  0.026261 -0.009062  0.008505  0.033554  0.010646  0.009660
# 2021-01-08  0.007109 -0.016388  0.014154  0.008594  0.005234  0.002782
# 2021-01-11  0.008542 -0.008629  0.005629 -0.023523  0.016182 -0.006923
# ...              ...       ...       ...       ...       ...       ...
# 2023-02-22 -0.009387 -0.008320 -0.003961  0.002892 -0.008788 -0.009305
# 2023-02-23  0.007852  0.019727 -0.011273  0.003285  0.009249 -0.001364
# 2023-02-24 -0.014065 -0.019727 -0.022503 -0.018169  0.004200 -0.020591
# 2023-02-27  0.006916  0.004489  0.012738  0.008214  0.010228 -0.006892
# 2023-02-28 -0.001478  0.022146  0.030325 -0.003454 -0.002466  0.019356
#
#                  AEP       AES       ALB       AMD  ...       RCL      REGN  \
# ...

# %%
portfolio_df = pd.DataFrame()

for start_date in fixed_dates.keys():
    
    end_date = (pd.to_datetime(start_date)+pd.offsets.MonthEnd()).strftime('%Y-%m-%d')
    
    cols = fixed_dates[start_date]
    
    temp_df = returns_df[start_date:end_date][cols].mean(axis=1).to_frame('portfolio_return')
    
    portfolio_df = pd.concat([portfolio_df, temp_df], axis=0)
    
portfolio_df
# Out:
#             portfolio_return
# Date
# 2021-12-01         -0.016417
# 2021-12-02          0.024872
# 2021-12-03         -0.007711
# 2021-12-06          0.023926
# 2021-12-07          0.030547
# ...                      ...
# 2023-02-22         -0.007870
# 2023-02-23         -0.007323
# 2023-02-24         -0.009463
# 2023-02-27         -0.001871
# 2023-02-28          0.001403
#
# [312 rows x 1 columns]

# %% [markdown]
# # 7. Download NASDAQ/QQQ prices and calculate returns to compare to our strategy

# %%
qqq_df = yf.download(tickers='QQQ',
                     start='2021-01-01',
                     end='2023-03-01')

qqq_ret = np.log(qqq_df['Adj Close']).diff().to_frame('nasdaq_return')

portfolio_df = portfolio_df.merge(qqq_ret,
                                  left_index=True,
                                  right_index=True)

portfolio_df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#             portfolio_return  nasdaq_return
# Date
# 2021-12-01         -0.016417      -0.017159
# 2021-12-02          0.024872       0.007181
# 2021-12-03         -0.007711      -0.017542
# 2021-12-06          0.023926       0.007981
# 2021-12-07          0.030547       0.029669
# ...                      ...            ...
# 2023-02-22         -0.007870       0.000748
# 2023-02-23         -0.007323       0.008696
# 2023-02-24         -0.009463      -0.016886
# 2023-02-27         -0.001871       0.007136
# 2023-02-28          0.001403      -0.001294
#
# [312 rows x 2 columns]

# %% [markdown]
# Now to visualize these two returns against each other

# %%
portfolios_cumulative_return = np.exp(np.log1p(portfolio_df).cumsum()).sub(1)

portfolios_cumulative_return.plot(figsize=(16,6))

plt.title('Twitter Engagement Ratio Strategy Over Time')

plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter(1))

plt.ylabel('Return')

plt.show()
